# %% [markdown]
# # Juliaで動かす金融計算-株価のシミュレーション
#
# さて, 乱数を使っていよいよ金融らしいことをやっていきましょう.
# ここでは, 乱数を使って株価のシミュレーションをやっていきます.

# %% [markdown]
# ## 株価のシミュレーションの準備

# %% [markdown]
# 株価のシミュレーションを行うわけですが, そのためには **どのように株価が変動するか** ということを決めておかなければなりません.
# これを **株価の「モデル」を決める** なんて言ったりします.
# 金融の世界では株価の変動について, 様々なモデルがありますが, ここでは株価の変動を
# $$
#     株価の変動 = 確定的な変動 + 確率的な変動
# $$
# と分けて考えてみたいと思います.
# 株価の変動を下記のように分けてみるわけですね.
#  ![stock_price_diff_decompositioin.png](attachment:stock_price_diff_decompositioin.png)

# %% [markdown]
# では, 「具体的にそれぞれの変動をどう計算するのか」という点について, 説明していきましょう.

# %% [markdown]
# ### 確定的な変動について

# %% [markdown]
# 確定的な変動の部分については, 以下のように計算することにしましょう.
# $$
#     確定的な変動 = \underbrace{期待収益率 \times 時間の刻み幅}_{=現在の株価に対する平均リターン分} \times 現在の株価
# $$
# 式でみると何をやっているかよくわからないかもしれませんが, 要するに **「確定的な変動⇒平均リターン分」** だということです.
# では, これを計算する関数を書いてみましょう.

# %%
"""
    CalcConstantDiff(μ, Δt, S)

期待収益率`μ`, 時間の刻み幅`Δt`, 現在の株価`S`から確定的な変動を計算する関数.  
"""
function CalcConstantDiff(μ, Δt, S) #μは\mu⇒Tabキーで, Δは\Delta⇒Tabキーで出ます. 
    return μ * Δt * S 
end
# Out:
# CalcConstantDiff

# %% [markdown]
# これで, 確定的な変動を計算する関数が作れました.
#
# （参考）
# ちなみに, コード中の`""" ... """`の部分は`Julia`の組み込みドキュメンテーション機能です.
# これをつけておくと, カーソルを当てたりしたときのヒントに, 自分で書いたコメントが表示されます.

# %% [markdown]
# ### 確率的な変動について
# さて, ここからが本講座の正念場である確率的な変動の計算です.
# といっても, 計算方法の概形は確定的な変動とあまり変わりません.
# 確率的な変動は以下のように計算することにしましょう.
# $$
# \begin{align*}
#     &確率的な変動 = \underbrace{ボラティリティ \times 乱数}_{=現在の株価に対するランダムの部分} \times 現在の株価 \\
#     &（乱数は平均0, 分散が時間の刻み幅である正規分布から生成したもの）
# \end{align*}
# $$
# ここで出てくるボラティリティというのは, 確率的な変動の大きさを司るものです.
# 確率的な変動についても難しく考える必要はありません. 結局は **「確率的な変動⇒現在の株価に対するランダムの部分」** です.
# 問題になるのは乱数の部分かと思いますが, これについては既にやりましたね.
# 注意する点としては, 分散が時間の刻み幅（=`Δt`）なので, 標準偏差はその0.5乗である`Δt^0.5`である点です.
# なぜこんな変な分散の設定をするのか？という至極真っ当な疑問を持つかもしれません.
# これについては数学的な背景があるのですが, それについて説明すると大変なので, まぁそういうものかと思ってください.
# さぁ, コードを書いてみましょう.

# %%
using  Distributions

"""
    CalcRandomDiff(σ, Δt, S)

ボラティリティ`σ`, 時間の刻み幅`Δt`, 現在の株価`S`から確率的な変動を計算する関数
"""
function CalcRandomDiff(σ, Δt, S) #σは\sigma⇒Tabキーで出ます.
    d = Normal(0, Δt^0.5)
    w = rand(d) #1個だけ乱数を生成するのでこれでOK
    return σ * w * S
end
# Out:
# CalcRandomDiff

# %% [markdown]
# ### 変動の実装

# %% [markdown]
# では, 今まで作成した関数を組み合わせて, 株価の変動を一気に出す関数を作っておきましょう.

# %%
function CalcDiff(μ, σ, Δt, S)
    c = CalcConstantDiff(μ, Δt, S)
    r = CalcRandomDiff(σ, Δt, S)
    return c + r
end
# Out:
# CalcDiff (generic function with 1 method)

# %% [markdown]
# ここで作成した変動を計算する関数`CalcDiff()`を使って, 株価の変動は以下のように計算することができます.
# `次の株価 = 現在の株価 + CalcDiff()`

# %% [markdown]
# ## 時間の実装

# %% [markdown]
# 株価は, 時間とともに移りゆくものなので, 当然時間についても考えておく必要があります.
# といってもそんなに難しく考える必要はありません.
# `Julia`なら1行で作ることができるからです.
# 以下実装（？）です.

# %%
function MakeTime(Δt, T)
    return 0:Δt:T #Δt刻みで, 0からTまでの時間を生成する
end
# Out:
# MakeTime (generic function with 1 method)

# %% [markdown]
# ## 株価のシミュレーションを実装

# %% [markdown]
# さて, 今までやってきたことを組み合わせて, 株価のシミュレーションを行いましょう.
# 株価のシミュレーションは以下の流れで行います.
#
# 1. 各定数を決める
# 1. 時間を作る
# 1. 時間ごとに株価の変動を計算する
# 1. 株価をプロットする

# %%
using Distributions
using StatsPlots

function SimulateStockPrice()
    #定数の設定
    T = 1
    Δt = 0.01

    μ = 0.5
    σ = 0.2

    #時間の生成
    t = MakeTime(Δt, T)

    S0 = 100.0 #初期株価
    S = [S0] #株価の配列を初期化

    #時間ごとに株価を生成
    for t_i in t[2:end] #初期化済みなので2から始める
        nextS = S[end] + CalcDiff(μ, σ, Δt, S[end]) #次の株価 = 現在の株価 + 株価の変動
        push!(S, nextS)
    end

    #株価をプロット
    plot(t, S, label = "StockPrice")
end

SimulateStockPrice()

# %% [markdown]
# 無事に株価が表示されましたでしょうか？
# ちょっとわかりにくい点があるとすれば, `t[2:end]`のところかと思います.
# これは以下のように, 一番最初は既に作っているので, 2番目から始めるという意味です.
#
# |インデックス|`t`|`S`||
# |:--|:--|:--|:--|
# |1|0|100|←`for`文の外で作成済み|
# |2|`Δt`|100 + 変動分|←ここからループして作る|
# |...|...|...||
# |`end`|`T`|`S[end]`|←これを作ってループ終了|

# %% [markdown]
# これで, 株価のシミュレーションができたことになります.
# 自分で数値をいろいろ変えてみると, また出てくる値が変化して面白いと思うので, ぜひ遊んでみてください.
#
# （数値の変え方のヒント）
# 1. `μ`を大きくしてみるとどうなるでしょう？逆に小さくすると？マイナスにすると？
# 2. `σ`を大きくしてみるとどうなるでしょう？（`σ`にはマイナス値は理論的には許されません. ご注意ください）
# 3. `σ`に0を設定するとどうなるでしょう？
# 4. `Δt`をもっと小さくしてみるとどうなるでしょう？（`Δt`には0より大きい値を入れてください）

# %% [markdown]
# ## （発展編）株価を複数生成して同時にプロット

# %% [markdown]
# ちょっとした発展事項として, 株価を複数生成して, 同時にプロットしてみましょう.

# %%
using Distributions
using StatsPlots

function SimulateMultiStockPrice(n)
    #定数の設定
    T = 1
    Δt = 0.01

    μ = 0.5
    σ = 0.2

    S0 = 100.0 #初期株価

    #時間の生成
    t = MakeTime(Δt, T)
    
    #プロットを描写する枠を確保
    p = plot()
    for i in 1:n
        S = [S0]
        #時間ごとに株価を生成
        for t_i in t[2:end] #初期化済みなので2から始める
            nextS = S[end] + CalcDiff(μ, σ, Δt, S[end]) #次の株価 = 現在の株価 + 株価の変動
            push!(S, nextS)
        end

        #株価のプロットをpに追加
        plot!(p, t, S, label = "Stock Price " * string(i)) #string(i)でiを文字列にキャスト
    end
    
    #グラフを描画
    display(p)
end

SimulateMultiStockPrice(5)
